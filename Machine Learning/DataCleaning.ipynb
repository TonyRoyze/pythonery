# %%
# %pip install polars
# %pip install polars
# %pip install polars

# %%
import numpy as np
import polars as pl
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cols_with_nans = [x for x in df if df[x].isnull().sum() > 0 ]
df[cols_with_nansl.isnull().sum()
